# %%
import pandas as pd
df = pd.read_csv('movie_metadata.csv')

# %%
df = df[pd.notnull(df['gross'])]
#df=df.drop(["director_facebook_likes",'actor_3_facebook_likes','actor_2_name','actor_1_facebook_likes','actor_2_facebook_likes'],1)
df
# Out:
#       duration        gross  \
# 0        178.0  760505847.0
# 1        169.0  309404152.0
# 2        148.0  200074175.0
# 3        164.0  448130642.0
# 5        132.0   73058679.0
# 6        156.0  336530303.0
# 7        100.0  200807262.0
# 8        141.0  458991599.0
# 9        153.0  301956980.0
# 10       183.0  330249062.0
# 11       169.0  200069408.0
# 12       106.0  168368427.0
# 13       151.0  423032628.0
# 14       150.0   89289910.0
# 15       143.0  291021565.0
# 16       150.0  141614023.0
# 17       173.0  623279547.0
# 18       136.0  241063875.0
# 19       106.0  179020854.0
# 20       164.0  255108370.0
# 21       153.0  262030663.0
# 22       156.0  105219735.0
# 23       186.0  258355354.0
# 24       113.0   70083519.0
# 25       201.0  218051260.0
# 26       194.0  658672302.0
# 27       147.0  407197282.0
# 28       131.0   65173160.0
# 29       124.0  652177271.0
# 30       143.0  304360277.0
# ...        ...          ...
# 4974      86.0      33598.0
# ...

# %%
]
